# %%
from robust_motifs.data import load_sparse_matrix_from_pkl
import numpy as np

# %%
a = np.array([[1,np.nan,np.nan],
              [1, np.nan, np.nan]])

# %%
from pathlib import Path
import pickle

# %%
import matplotlib.pyplot as plt

# %%
p = Path("data/activity/spikes/evoked/seed181842")

# %%
a = pickle.load(open(p / "simplexwise_pc_all.pkl", 'rb'))
b = pickle.load(open(p / "simplexwise_pc_spine.pkl", 'rb'))
c = pickle.load(open(p / "simplexwise_pc.pkl", 'rb'))

# %%
plt.errorbar(range(1,7), c[0][0], label = 'End')
plt.errorbar(range(1,7), b[0][0], label = 'Spine')
plt.errorbar(range(1,7), a[0][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in bidirectional edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[1][0], label = 'End')
plt.errorbar(range(1,7), b[1][0], label = 'Spine')
plt.errorbar(range(1,7), a[1][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in directed edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[2][0], label = 'End')
plt.errorbar(range(1,7), b[2][0], label = 'Spine')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in all edges")
plt.legend()

# %%
plt.errorbar(range(1,7), b[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), b[1][0], label = 'Directed')
plt.errorbar(range(1,7), b[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), a[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), a[1][0], label = 'Directed')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in spine of simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), c[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), c[1][0], label = 'Directed')
plt.errorbar(range(1,7), c[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in end of simplices")
plt.legend()

# %%
p = Path("data/activity/spikes/evoked/seed25888/")

# %%
a = pickle.load(open(p / "simplexwise_pc_all.pkl", 'rb'))
b = pickle.load(open(p / "simplexwise_pc_spine.pkl", 'rb'))
c = pickle.load(open(p / "simplexwise_pc.pkl", 'rb'))

# %%
plt.errorbar(range(1,7), c[0][0], label = 'End')
plt.errorbar(range(1,7), b[0][0], label = 'Spine')
plt.errorbar(range(1,7), a[0][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in bidirectional edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[1][0], label = 'End')
plt.errorbar(range(1,7), b[1][0], label = 'Spine')
plt.errorbar(range(1,7), a[1][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in directed edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[2][0], label = 'End')
plt.errorbar(range(1,7), b[2][0], label = 'Spine')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in all edges")
plt.legend()

# %%
plt.errorbar(range(1,7), b[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), b[1][0], label = 'Directed')
plt.errorbar(range(1,7), b[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), a[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), a[1][0], label = 'Directed')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in spine of simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), c[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), c[1][0], label = 'Directed')
plt.errorbar(range(1,7), c[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in end of simplices")
plt.legend()

# %%
p = Path("data/activity/spikes/evoked/seed282267/")

# %%
a = pickle.load(open(p / "simplexwise_pc_all.pkl", 'rb'))
b = pickle.load(open(p / "simplexwise_pc_spine.pkl", 'rb'))
c = pickle.load(open(p / "simplexwise_pc.pkl", 'rb'))

# %%
plt.errorbar(range(1,7), c[0][0], label = 'End')
plt.errorbar(range(1,7), b[0][0], label = 'Spine')
plt.errorbar(range(1,7), a[0][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in bidirectional edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[1][0], label = 'End')
plt.errorbar(range(1,7), b[1][0], label = 'Spine')
plt.errorbar(range(1,7), a[1][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in directed edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[2][0], label = 'End')
plt.errorbar(range(1,7), b[2][0], label = 'Spine')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in all edges")
plt.legend()

# %%
plt.errorbar(range(1,7), b[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), b[1][0], label = 'Directed')
plt.errorbar(range(1,7), b[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), a[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), a[1][0], label = 'Directed')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in spine of simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), c[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), c[1][0], label = 'Directed')
plt.errorbar(range(1,7), c[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in end of simplices")
plt.legend()

# %%
p = Path("data/activity/spikes/spont/seed134276/")

# %%
p1 = Path("data/activity/spikes/spont/seed134276/pearson_correlation.pkl")

# %%
a = pickle.load(open(p1, 'rb'))

# %%
a.shape
# Out:
# (21702, 21702)

# %%
np.triu(a,1 )
# Out:
# (21702, 21702)

# %%
np.average(np.triu(a, 1))
# Out:
# 0.0008565298675414849

# %%
a = pickle.load(open(p / "simplexwise_pc_all.pkl", 'rb'))
b = pickle.load(open(p / "simplexwise_pc_spine.pkl", 'rb'))
c = pickle.load(open(p / "simplexwise_pc.pkl", 'rb'))

# %%
plt.errorbar(range(1,7), c[0][0], label = 'End')
plt.errorbar(range(1,7), b[0][0], label = 'Spine')
plt.errorbar(range(1,7), a[0][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in bidirectional edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[1][0], label = 'End')
plt.errorbar(range(1,7), b[1][0], label = 'Spine')
plt.errorbar(range(1,7), a[1][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in directed edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[2][0], label = 'End')
plt.errorbar(range(1,7), b[2][0], label = 'Spine')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in all edges")
plt.legend()

# %%
plt.errorbar(range(1,7), b[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), b[1][0], label = 'Directed')
plt.errorbar(range(1,7), b[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), a[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), a[1][0], label = 'Directed')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in spine of simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), c[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), c[1][0], label = 'Directed')
plt.errorbar(range(1,7), c[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in end of simplices")
plt.legend()

# %%
p = Path("data/activity/spikes/spont/seed38290//")

# %%
a = pickle.load(open(p / "simplexwise_pc_all.pkl", 'rb'))
b = pickle.load(open(p / "simplexwise_pc_spine.pkl", 'rb'))
c = pickle.load(open(p / "simplexwise_pc.pkl", 'rb'))

# %%
plt.errorbar(range(1,7), c[0][0], label = 'End')
plt.errorbar(range(1,7), b[0][0], label = 'Spine')
plt.errorbar(range(1,7), a[0][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in bidirectional edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[1][0], label = 'End')
plt.errorbar(range(1,7), b[1][0], label = 'Spine')
plt.errorbar(range(1,7), a[1][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in directed edges")
plt.legend()

# %%
plt.errorbar(range(1,7), c[2][0], label = 'End')
plt.errorbar(range(1,7), b[2][0], label = 'Spine')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in all edges")
plt.legend()

# %%
plt.errorbar(range(1,7), b[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), b[1][0], label = 'Directed')
plt.errorbar(range(1,7), b[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), a[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), a[1][0], label = 'Directed')
plt.errorbar(range(1,7), a[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in spine of simplices")
plt.legend()

# %%
plt.errorbar(range(1,7), c[0][0], label = 'Bidirectional')
plt.errorbar(range(1,7), c[1][0], label = 'Directed')
plt.errorbar(range(1,7), c[2][0], label = 'All')
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in end of simplices")
plt.legend()

# %%
abid = np.zeros((6,), dtype = float)
adir = np.zeros((6,), dtype = float)
aall = np.zeros((6,), dtype = float)

bbid = np.zeros((6,), dtype = float)
bdir = np.zeros((6,), dtype = float)
ball = np.zeros((6,), dtype = float)

cbid = np.zeros((6,), dtype = float)
cdir = np.zeros((6,), dtype = float)
call = np.zeros((6,), dtype = float)

for seed in Path("data/activity/spikes/evoked").glob("*"):
    a = pickle.load(open(p / "simplexwise_pc_all.pkl", 'rb'))
    abid += a[0][0]
    adir += a[1][0]
    aall += a[2][0]
    b = pickle.load(open(p / "simplexwise_pc_spine.pkl", 'rb'))
    bbid += b[0][0]
    bdir += b[1][0]
    ball += b[2][0]
    c = pickle.load(open(p / "simplexwise_pc.pkl", 'rb'))
    cbid += c[0][0]
    cdir += c[1][0]
    call += c[2][0]
abid/=20
adir/=20
aall/=20
bbid/=20
bdir/=20
ball/=20
cbid/=20
cdir/=20
call/=20

# %%
plt.plot(range(1,7), abid, label = 'Bidirectional')
plt.plot(range(1,7), adir, label = 'Directed')
plt.plot(range(1,7), aall, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in simplices")
# Out:
# Text(0.5, 1.0, 'Correlation in simplices')

# %%
plt.plot(range(1,7), bbid, label = 'Bidirectional')
plt.plot(range(1,7), bdir, label = 'Directed')
plt.plot(range(1,7), ball, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in spine of simplices")
# Out:
# Text(0.5, 1.0, 'Correlation in spine of simplices')

# %%
plt.plot(range(1,7), cbid, label = 'Bidirectional')
plt.plot(range(1,7), cdir, label = 'Directed')
plt.plot(range(1,7), call, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in end of simplices")
# Out:
# Text(0.5, 1.0, 'Correlation in end of simplices')

# %%
plt.plot(range(1,7), cbid, label = 'End')
plt.plot(range(1,7), bbid, label = 'Spine')
plt.plot(range(1,7), abid, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in bidirectional edges")
# Out:
# Text(0.5, 1.0, 'Correlation in bidirectional edges')

# %%
plt.plot(range(1,7), cdir, label = 'End')
plt.plot(range(1,7), bdir, label = 'Spine')
plt.plot(range(1,7), adir, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in directed edges")
# Out:
# Text(0.5, 1.0, 'Correlation in directed edges')

# %%
plt.plot(range(1,7), call, label = 'End')
plt.plot(range(1,7), ball, label = 'Spine')
plt.plot(range(1,7), aall, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in all edges")
# Out:
# Text(0.5, 1.0, 'Correlation in all edges')

# %%
abid = np.zeros((6,), dtype = float)
adir = np.zeros((6,), dtype = float)
aall = np.zeros((6,), dtype = float)

bbid = np.zeros((6,), dtype = float)
bdir = np.zeros((6,), dtype = float)
ball = np.zeros((6,), dtype = float)

cbid = np.zeros((6,), dtype = float)
cdir = np.zeros((6,), dtype = float)
call = np.zeros((6,), dtype = float)

for seed in Path("data/activity/spikes/spont").glob("*"):
    a = pickle.load(open(p / "simplexwise_pc_all.pkl", 'rb'))
    abid += a[0][0]
    adir += a[1][0]
    aall += a[2][0]
    b = pickle.load(open(p / "simplexwise_pc_spine.pkl", 'rb'))
    bbid += b[0][0]
    bdir += b[1][0]
    ball += b[2][0]
    c = pickle.load(open(p / "simplexwise_pc.pkl", 'rb'))
    cbid += c[0][0]
    cdir += c[1][0]
    call += c[2][0]
abid/=3
adir/=3
aall/=3
bbid/=3
bdir/=3
ball/=3
cbid/=3
cdir/=3
call/=3

# %%
plt.plot(range(1,7), abid, label = 'Bidirectional')
plt.plot(range(1,7), adir, label = 'Directed')
plt.plot(range(1,7), aall, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in simplices")
# Out:
# Text(0.5, 1.0, 'Correlation in simplices')

# %%
plt.plot(range(1,7), bbid, label = 'Bidirectional')
plt.plot(range(1,7), bdir, label = 'Directed')
plt.plot(range(1,7), ball, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in spine of simplices")
# Out:
# Text(0.5, 1.0, 'Correlation in spine of simplices')

# %%
plt.plot(range(1,7), cbid, label = 'Bidirectional')
plt.plot(range(1,7), cdir, label = 'Directed')
plt.plot(range(1,7), call, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in end of simplices")
# Out:
# Text(0.5, 1.0, 'Correlation in end of simplices')

# %%
plt.plot(range(1,7), cbid, label = 'End')
plt.plot(range(1,7), bbid, label = 'Spine')
plt.plot(range(1,7), abid, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in bidirectional edges")
# Out:
# Text(0.5, 1.0, 'Correlation in bidirectional edges')

# %%
plt.plot(range(1,7), cdir, label = 'End')
plt.plot(range(1,7), bdir, label = 'Spine')
plt.plot(range(1,7), adir, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in directed edges")
# Out:
# Text(0.5, 1.0, 'Correlation in directed edges')

# %%
plt.plot(range(1,7), call, label = 'End')
plt.plot(range(1,7), ball, label = 'Spine')
plt.plot(range(1,7), aall, label = 'All')
plt.legend()
plt.xlabel("Dimension")
plt.ylabel("Correlation")
plt.title("Correlation in all edges")
# Out:
# Text(0.5, 1.0, 'Correlation in all edges')
